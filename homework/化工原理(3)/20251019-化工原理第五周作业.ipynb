# %% [markdown]
# # 化工原理第五周作业

# %%
from chemetk import VLE, McCabeThiele,plot_mccabe_thiele
from chemetk.data import get_vle_file_path

# 构建数据文件的路径
data_path=get_vle_file_path("methanol_water_vle")
assert data_path is not None, "未找到methanol_water_vle数据文件路径"
vle = VLE(data_path=data_path)

# %% [markdown]
# ## 5-2

# %%
# x_D=0.922,x_W=0.021的情况
F, x_F = 0, 0
D, x_D = 0, 0.922
W, x_W = 0, 0.021

column = McCabeThiele(vle=vle, x_D=x_D, x_W=x_W, x_F=x_F, q=1, R=1e10,D=D,W=W,F=F)
result,decimal_stages = column.calculate_stages(start_from='top',return_decimal_stages=True)
column.print_summary(result, calculation_direction='top', decimal_stages=decimal_stages)
# Out:
# 检测到全回流操作模式
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.021
# 液相Murphree效率 E_ml = 1.0
# 操作模式: 全回流
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9220, y = 0.9220, 温度 = 65.8°C, 段别 = 全回流段
# 第 2级: x = 0.8077, y = 0.9220, 温度 = 67.6°C, 段别 = 全回流段
# 第 3级: x = 0.5393, y = 0.8077, 温度 = 72.3°C, 段别 = 全回流段
# 第 4级: x = 0.1674, y = 0.5393, 温度 = 83.5°C, 段别 = 全回流段
# 第 5级: x = 0.0258, y = 0.1674, 温度 = 95.6°C, 段别 = 全回流段
# 第 6级: x = 0.0035, y = 0.0258, 温度 = 99.3°C, 段别 = 全回流段
# 达到目标釜液组成 x_W = 0.021
# 小数理论级数计算: 第4级x=0.0258, 第5级x=0.0035
# 在x_W=0.021处插值, 小数部分 = 0.216
# 总小数理论级数 = 4.216
#
# ==========================================================================================
# 全回流精馏塔理论塔板计算汇总 (从塔顶开始)
# ==========================================================================================
# 塔板级数       液相组成(x)      气相组成(y)      温度(℃)      效率       段别
# ------------------------------------------------------------------------------------------
# 1          0.9220       0.9220       65.8       1.00     全回流段
# 2          0.8077       0.9220       67.6       1.00     全回流段
# 3          0.5393       0.8077       72.3       1.00     全回流段
# 4          0.1674       0.5393       83.5       1.00     全回流段
# 5          0.0258       0.1674       95.6       1.00     全回流段
# 6          0.0035       0.0258       99.3       1.00     全回流段
# ------------------------------------------------------------------------------------------
# 整数理论塔板数: 6 级
# 小数理论塔板数: 4.216 级
# 全塔板效率计算用理论级数: 4.216

# %%
# x_D=0.932,x_W=0.020的情况
F, x_F = 0, 0
D, x_D = 0, 0.932
W, x_W = 0, 0.020

column = McCabeThiele(vle=vle, x_D=x_D, x_W=x_W, x_F=x_F, q=1, R=1e10,D=D,W=W,F=F)
result,decimal_stages = column.calculate_stages(start_from='top',return_decimal_stages=True)
column.print_summary(result, calculation_direction='top', decimal_stages=decimal_stages)
# Out:
# 检测到全回流操作模式
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.02
# 液相Murphree效率 E_ml = 1.0
# 操作模式: 全回流
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9320, y = 0.9320, 温度 = 65.6°C, 段别 = 全回流段
# 第 2级: x = 0.8311, y = 0.9320, 温度 = 67.2°C, 段别 = 全回流段
# 第 3级: x = 0.5913, y = 0.8311, 温度 = 71.4°C, 段别 = 全回流段
# 第 4级: x = 0.2100, y = 0.5913, 温度 = 81.5°C, 段别 = 全回流段
# 第 5级: x = 0.0344, y = 0.2100, 温度 = 94.4°C, 段别 = 全回流段
# 第 6级: x = 0.0047, y = 0.0344, 温度 = 99.1°C, 段别 = 全回流段
# 达到目标釜液组成 x_W = 0.02
# 小数理论级数计算: 第4级x=0.0344, 第5级x=0.0047
# 在x_W=0.02处插值, 小数部分 = 0.484
# 总小数理论级数 = 4.484
#
# ==========================================================================================
# 全回流精馏塔理论塔板计算汇总 (从塔顶开始)
# ==========================================================================================
# 塔板级数       液相组成(x)      气相组成(y)      温度(℃)      效率       段别
# ------------------------------------------------------------------------------------------
# 1          0.9320       0.9320       65.6       1.00     全回流段
# 2          0.8311       0.9320       67.2       1.00     全回流段
# 3          0.5913       0.8311       71.4       1.00     全回流段
# 4          0.2100       0.5913       81.5       1.00     全回流段
# 5          0.0344       0.2100       94.4       1.00     全回流段
# 6          0.0047       0.0344       99.1       1.00     全回流段
# ------------------------------------------------------------------------------------------
# 整数理论塔板数: 6 级
# 小数理论塔板数: 4.484 级
# 全塔板效率计算用理论级数: 4.484

# %% [markdown]
# ## 5-3

# %%
# 原情况
F, x_F = 100, 0.48
D, x_D = 52.8, 0.9
W, x_W = 47.2, 0.01

column = McCabeThiele(vle=vle, x_D=x_D, x_W=x_W, x_F=x_F, q=1, R=0.6,D=D,W=W,F=F)
result = column.calculate_stages(start_from='top')
column.print_summary(result, calculation_direction='top')
# Out:
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9000, y = 0.9000, 温度 = 66.1°C, 段别 = 精馏段
# 第 2级: x = 0.7523, y = 0.9000, 温度 = 68.5°C, 段别 = 精馏段
# 第 3级: x = 0.6213, y = 0.8446, 温度 = 70.8°C, 段别 = 精馏段
# 第 4级: x = 0.5128, y = 0.7955, 温度 = 72.8°C, 段别 = 精馏段
# 第 5级: x = 0.4322, y = 0.7548, 温度 = 74.7°C, 段别 = 提馏段
# 第 6级: x = 0.2949, y = 0.6681, 温度 = 78.3°C, 段别 = 提馏段
# 第 7级: x = 0.1155, y = 0.4541, 温度 = 86.6°C, 段别 = 提馏段
# 第 8级: x = 0.0272, y = 0.1745, 温度 = 95.4°C, 段别 = 提馏段
# 第 9级: x = 0.0050, y = 0.0368, 温度 = 99.0°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
#
# ==========================================================================================
# 精馏塔理论塔板计算汇总 (从塔顶开始，考虑液相Murphree效率)
# ==========================================================================================
# 塔板级数       液相组成(x)      气相组成(y)      温度(℃)      效率       段别
# ------------------------------------------------------------------------------------------
# 1          0.9000       0.9000       66.1       1.00     精馏段
# 2          0.7523       0.9000       68.5       1.00     精馏段
# 3          0.6213       0.8446       70.8       1.00     精馏段
# 4          0.5128       0.7955       72.8       1.00     精馏段
# 5          0.4322       0.7548       74.7       1.00     提馏段
# 6          0.2949       0.6681       78.3       1.00     提馏段
# 7          0.1155       0.4541       86.6       1.00     提馏段
# 8          0.0272       0.1745       95.4       1.00     提馏段
# 9          0.0050       0.0368       99.0       1.00     提馏段
# ------------------------------------------------------------------------------------------
# 整数理论塔板数: 9 级
# 其中精馏段: 4 级
# 其中提馏段: 5 级
# 进料板位置: 第5级

# %%
import numpy as np
import matplotlib.pyplot as plt

# 已知参数
F, x_F = 100, 0.48
D, x_D = 50, 0.95
W, x_W = 50, 0.01
target_stages = 8  # 目标板数

# 计算不同回流比下的理论板数
R = np.linspace(0.1, 10, 100)
stages=[len(McCabeThiele(vle=vle, x_D=x_D, x_W=x_W, x_F=x_F, q=1, R=r,D=D,W=W,F=F).calculate_stages(start_from='top'))-1 for r in R]

# 找到理论板数等于目标板数的回流比（考虑数值计算误差）
tolerance = 1e-6  # 容差
mask = np.isclose(stages, target_stages, atol=tolerance)
intersection_R = R[mask]

# 提取第一个和最后一个交点（若存在）
if len(intersection_R) > 0:
    first_R = intersection_R[0]  # 第一个交点的回流比
    last_R = intersection_R[-1]  # 最后一个交点的回流比
else:
    first_R = last_R = None
    print("未找到交点")

# 绘图
plt.figure(figsize=(10, 6))
plt.plot(R, stages, label='Number of Stages vs Reflux Ratio')
plt.plot(R, [target_stages]*len(R), 'r--', label=f'Target Stages ({target_stages})')

# 标记交点
if first_R is not None and last_R is not None:
    plt.scatter([first_R, last_R], [target_stages, target_stages], 
                color='blue', s=100, zorder=5, label='Intersections')
    # 标注交点坐标
    plt.text(first_R, target_stages+5, f'({first_R:.2f}, {target_stages})', 
             ha='center', color='blue')
    plt.text(last_R, target_stages-5, f'({last_R:.2f}, {target_stages})', 
             ha='center', color='blue')

plt.xlabel("Reflux Ratio (R)")
plt.ylabel("Number of Stages")
plt.title("Effect of Reflux Ratio on Number of Stages")
plt.grid(alpha=0.3)
plt.legend()
plt.show()
# Out:
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.8579, y = 0.9432, 温度 = 66.7°C, 段别 = 精馏段
# 第 4级: x = 0.8539, y = 0.9416, 温度 = 66.8°C, 段别 = 精馏段
# 第 5级: x = 0.8530, y = 0.9413, 温度 = 66.8°C, 段别 = 精馏段
# 第 6级: x = 0.8528, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第 7级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第 8级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第 9级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第10级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第11级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第12级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第13级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第14级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第15级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第16级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第17级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第18级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第19级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第20级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第21级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第22级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第23级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第24级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第25级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第26级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第27级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第28级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第29级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第30级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第31级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第32级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第33级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第34级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第35级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第36级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第37级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第38级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第39级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第40级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第41级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第42级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第43级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第44级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第45级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第46级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第47级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第48级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第49级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第50级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第51级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第52级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第53级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第54级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第55级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第56级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第57级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第58级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第59级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第60级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第61级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第62级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第63级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第64级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第65级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第66级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第67级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第68级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第69级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第70级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第71级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第72级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第73级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第74级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第75级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第76级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第77级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第78级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第79级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第80级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第81级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第82级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第83级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第84级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第85级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第86级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第87级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第88级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第89级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第90级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第91级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第92级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第93级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第94级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第95级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第96级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第97级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第98级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第99级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 第100级: x = 0.8527, y = 0.9412, 温度 = 66.8°C, 段别 = 精馏段
# 警告: 迭代次数超过100次，强制停止
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.8436, y = 0.9375, 温度 = 66.9°C, 段别 = 精馏段
# 第 4级: x = 0.8317, y = 0.9323, 温度 = 67.2°C, 段别 = 精馏段
# 第 5级: x = 0.8273, y = 0.9303, 温度 = 67.3°C, 段别 = 精馏段
# 第 6级: x = 0.8258, y = 0.9296, 温度 = 67.3°C, 段别 = 精馏段
# 第 7级: x = 0.8252, y = 0.9293, 温度 = 67.3°C, 段别 = 精馏段
# 第 8级: x = 0.8250, y = 0.9292, 温度 = 67.3°C, 段别 = 精馏段
# 第 9级: x = 0.8249, y = 0.9292, 温度 = 67.3°C, 段别 = 精馏段
# 第10级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第11级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第12级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第13级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第14级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第15级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第16级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第17级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第18级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第19级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第20级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第21级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第22级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第23级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第24级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第25级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第26级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第27级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第28级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第29级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第30级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第31级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第32级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第33级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第34级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第35级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第36级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第37级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第38级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第39级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第40级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第41级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第42级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第43级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第44级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第45级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第46级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第47级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第48级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第49级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第50级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第51级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第52级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第53级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第54级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第55级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第56级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第57级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第58级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第59级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第60级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第61级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第62级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第63级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第64级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第65级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第66级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第67级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第68级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第69级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第70级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第71级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第72级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第73级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第74级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第75级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第76级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第77级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第78级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第79级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第80级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第81级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第82级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第83级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第84级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第85级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第86级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第87级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第88级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第89级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第90级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第91级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第92级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第93级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第94级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第95级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第96级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第97级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第98级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第99级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 第100级: x = 0.8249, y = 0.9291, 温度 = 67.3°C, 段别 = 精馏段
# 警告: 迭代次数超过100次，强制停止
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.8326, y = 0.9327, 温度 = 67.1°C, 段别 = 精馏段
# 第 4级: x = 0.8100, y = 0.9229, 温度 = 67.6°C, 段别 = 精馏段
# 第 5级: x = 0.7967, y = 0.9177, 温度 = 67.7°C, 段别 = 精馏段
# 第 6级: x = 0.7890, y = 0.9146, 温度 = 67.9°C, 段别 = 精馏段
# 第 7级: x = 0.7846, y = 0.9128, 温度 = 67.9°C, 段别 = 精馏段
# 第 8级: x = 0.7820, y = 0.9118, 温度 = 68.0°C, 段别 = 精馏段
# 第 9级: x = 0.7806, y = 0.9112, 温度 = 68.0°C, 段别 = 精馏段
# 第10级: x = 0.7798, y = 0.9109, 温度 = 68.0°C, 段别 = 精馏段
# 第11级: x = 0.7793, y = 0.9107, 温度 = 68.0°C, 段别 = 精馏段
# 第12级: x = 0.7790, y = 0.9106, 温度 = 68.0°C, 段别 = 精馏段
# 第13级: x = 0.7789, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第14级: x = 0.7788, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第15级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第16级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第17级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第18级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第19级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第20级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第21级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第22级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第23级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第24级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第25级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第26级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第27级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第28级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第29级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第30级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第31级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第32级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第33级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第34级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第35级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第36级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第37级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第38级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第39级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第40级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第41级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第42级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第43级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第44级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第45级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第46级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第47级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第48级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第49级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第50级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第51级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第52级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第53级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第54级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第55级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第56级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第57级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第58级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第59级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第60级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第61级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第62级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第63级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第64级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第65级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第66级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第67级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第68级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第69级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第70级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第71级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第72级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第73级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第74级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第75级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第76级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第77级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第78级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第79级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第80级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第81级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第82级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第83级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第84级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第85级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第86级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第87级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第88级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第89级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第90级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第91级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第92级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第93级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第94级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第95级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第96级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第97级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第98级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第99级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 第100级: x = 0.7787, y = 0.9105, 温度 = 68.0°C, 段别 = 精馏段
# 警告: 迭代次数超过100次，强制停止
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.8236, y = 0.9286, 温度 = 67.3°C, 段别 = 精馏段
# 第 4级: x = 0.7872, y = 0.9139, 温度 = 67.9°C, 段别 = 精馏段
# 第 5级: x = 0.7612, y = 0.9035, 温度 = 68.4°C, 段别 = 精馏段
# 第 6级: x = 0.7425, y = 0.8961, 温度 = 68.7°C, 段别 = 精馏段
# 第 7级: x = 0.7305, y = 0.8907, 温度 = 68.8°C, 段别 = 精馏段
# 第 8级: x = 0.7229, y = 0.8873, 温度 = 68.9°C, 段别 = 精馏段
# 第 9级: x = 0.7179, y = 0.8851, 温度 = 69.0°C, 段别 = 精馏段
# 第10级: x = 0.7145, y = 0.8837, 温度 = 69.1°C, 段别 = 精馏段
# 第11级: x = 0.7121, y = 0.8827, 温度 = 69.2°C, 段别 = 精馏段
# 第12级: x = 0.7103, y = 0.8820, 温度 = 69.2°C, 段别 = 精馏段
# 第13级: x = 0.7091, y = 0.8815, 温度 = 69.2°C, 段别 = 精馏段
# 第14级: x = 0.7081, y = 0.8812, 温度 = 69.2°C, 段别 = 精馏段
# 第15级: x = 0.7075, y = 0.8809, 温度 = 69.3°C, 段别 = 精馏段
# 第16级: x = 0.7070, y = 0.8807, 温度 = 69.3°C, 段别 = 精馏段
# 第17级: x = 0.7066, y = 0.8806, 温度 = 69.3°C, 段别 = 精馏段
# 第18级: x = 0.7064, y = 0.8805, 温度 = 69.3°C, 段别 = 精馏段
# 第19级: x = 0.7062, y = 0.8804, 温度 = 69.3°C, 段别 = 精馏段
# 第20级: x = 0.7060, y = 0.8803, 温度 = 69.3°C, 段别 = 精馏段
# 第21级: x = 0.7059, y = 0.8803, 温度 = 69.3°C, 段别 = 精馏段
# 第22级: x = 0.7059, y = 0.8803, 温度 = 69.3°C, 段别 = 精馏段
# 第23级: x = 0.7058, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第24级: x = 0.7058, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第25级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第26级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第27级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第28级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第29级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第30级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第31级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第32级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第33级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第34级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第35级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第36级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第37级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第38级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第39级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第40级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第41级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第42级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第43级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第44级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第45级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第46级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第47级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第48级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第49级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第50级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第51级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第52级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第53级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第54级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第55级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第56级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第57级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第58级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第59级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第60级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第61级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第62级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第63级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第64级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第65级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第66级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第67级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第68级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第69级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第70级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第71级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第72级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第73级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第74级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第75级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第76级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第77级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第78级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第79级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第80级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第81级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第82级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第83级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第84级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第85级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第86级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第87级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第88级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第89级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第90级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第91级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第92级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第93级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第94级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第95级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第96级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第97级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第98级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第99级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 第100级: x = 0.7057, y = 0.8802, 温度 = 69.3°C, 段别 = 精馏段
# 警告: 迭代次数超过100次，强制停止
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.8152, y = 0.9250, 温度 = 67.5°C, 段别 = 精馏段
# 第 4级: x = 0.7653, y = 0.9051, 温度 = 68.3°C, 段别 = 精馏段
# 第 5级: x = 0.7254, y = 0.8884, 温度 = 68.9°C, 段别 = 精馏段
# 第 6级: x = 0.6926, y = 0.8751, 温度 = 69.5°C, 段别 = 精馏段
# 第 7级: x = 0.6673, y = 0.8642, 温度 = 70.0°C, 段别 = 精馏段
# 第 8级: x = 0.6469, y = 0.8558, 温度 = 70.3°C, 段别 = 精馏段
# 第 9级: x = 0.6307, y = 0.8490, 温度 = 70.6°C, 段别 = 精馏段
# 第10级: x = 0.6191, y = 0.8436, 温度 = 70.8°C, 段别 = 精馏段
# 第11级: x = 0.6105, y = 0.8397, 温度 = 71.0°C, 段别 = 精馏段
# 第12级: x = 0.6041, y = 0.8368, 温度 = 71.1°C, 段别 = 精馏段
# 第13级: x = 0.5993, y = 0.8347, 温度 = 71.2°C, 段别 = 精馏段
# 第14级: x = 0.5958, y = 0.8331, 温度 = 71.3°C, 段别 = 精馏段
# 第15级: x = 0.5932, y = 0.8319, 温度 = 71.3°C, 段别 = 精馏段
# 第16级: x = 0.5912, y = 0.8311, 温度 = 71.4°C, 段别 = 精馏段
# 第17级: x = 0.5898, y = 0.8304, 温度 = 71.4°C, 段别 = 精馏段
# 第18级: x = 0.5887, y = 0.8299, 温度 = 71.4°C, 段别 = 精馏段
# 第19级: x = 0.5879, y = 0.8296, 温度 = 71.5°C, 段别 = 精馏段
# 第20级: x = 0.5873, y = 0.8293, 温度 = 71.5°C, 段别 = 精馏段
# 第21级: x = 0.5869, y = 0.8291, 温度 = 71.5°C, 段别 = 精馏段
# 第22级: x = 0.5866, y = 0.8290, 温度 = 71.5°C, 段别 = 精馏段
# 第23级: x = 0.5863, y = 0.8289, 温度 = 71.5°C, 段别 = 精馏段
# 第24级: x = 0.5862, y = 0.8288, 温度 = 71.5°C, 段别 = 精馏段
# 第25级: x = 0.5860, y = 0.8287, 温度 = 71.5°C, 段别 = 精馏段
# 第26级: x = 0.5859, y = 0.8287, 温度 = 71.5°C, 段别 = 精馏段
# 第27级: x = 0.5859, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第28级: x = 0.5858, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第29级: x = 0.5858, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第30级: x = 0.5858, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第31级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第32级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第33级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第34级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第35级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第36级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第37级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第38级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第39级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第40级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第41级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第42级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第43级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第44级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第45级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第46级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第47级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第48级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第49级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第50级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第51级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第52级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第53级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第54级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第55级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第56级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第57级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第58级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第59级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第60级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第61级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第62级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第63级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第64级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第65级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第66级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第67级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第68级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第69级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第70级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第71级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第72级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第73级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第74级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第75级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第76级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第77级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第78级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第79级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第80级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第81级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第82级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第83级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第84级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第85级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第86级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第87级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第88级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第89级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第90级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第91级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第92级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第93级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第94级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第95级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第96级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第97级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第98级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第99级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 第100级: x = 0.5857, y = 0.8286, 温度 = 71.5°C, 段别 = 精馏段
# 警告: 迭代次数超过100次，强制停止
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.8074, y = 0.9219, 温度 = 67.6°C, 段别 = 精馏段
# 第 4级: x = 0.7436, y = 0.8965, 温度 = 68.7°C, 段别 = 精馏段
# 第 5级: x = 0.6862, y = 0.8726, 温度 = 69.6°C, 段别 = 精馏段
# 第 6级: x = 0.6355, y = 0.8511, 温度 = 70.5°C, 段别 = 精馏段
# 第 7级: x = 0.5935, y = 0.8321, 温度 = 71.3°C, 段别 = 精馏段
# 第 8级: x = 0.5584, y = 0.8163, 温度 = 71.9°C, 段别 = 精馏段
# 第 9级: x = 0.5291, y = 0.8032, 温度 = 72.5°C, 段别 = 精馏段
# 第10级: x = 0.5062, y = 0.7922, 温度 = 73.0°C, 段别 = 精馏段
# 第11级: x = 0.4892, y = 0.7836, 温度 = 73.4°C, 段别 = 精馏段
# 第12级: x = 0.4764, y = 0.7772, 温度 = 73.7°C, 段别 = 提馏段
# 第13级: x = 0.4578, y = 0.7679, 温度 = 74.1°C, 段别 = 提馏段
# 第14级: x = 0.4011, y = 0.7376, 温度 = 75.4°C, 段别 = 提馏段
# 第15级: x = 0.2668, y = 0.6455, 温度 = 79.2°C, 段别 = 提馏段
# 第16级: x = 0.1028, y = 0.4272, 温度 = 87.6°C, 段别 = 提馏段
# 第17级: x = 0.0246, y = 0.1608, 温度 = 95.8°C, 段别 = 提馏段
# 第18级: x = 0.0046, y = 0.0337, 温度 = 99.1°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.8003, y = 0.9191, 温度 = 67.7°C, 段别 = 精馏段
# 第 4级: x = 0.7253, y = 0.8884, 温度 = 68.9°C, 段别 = 精馏段
# 第 5级: x = 0.6513, y = 0.8575, 温度 = 70.2°C, 段别 = 精馏段
# 第 6级: x = 0.5822, y = 0.8270, 温度 = 71.6°C, 段别 = 精馏段
# 第 7级: x = 0.5191, y = 0.7986, 温度 = 72.7°C, 段别 = 精馏段
# 第 8级: x = 0.4672, y = 0.7726, 温度 = 73.9°C, 段别 = 提馏段
# 第 9级: x = 0.3984, y = 0.7361, 温度 = 75.4°C, 段别 = 提馏段
# 第10级: x = 0.2452, y = 0.6269, 温度 = 80.1°C, 段别 = 提馏段
# 第11级: x = 0.0844, y = 0.3835, 温度 = 89.1°C, 段别 = 提馏段
# 第12级: x = 0.0188, y = 0.1281, 温度 = 96.7°C, 段别 = 提馏段
# 第13级: x = 0.0032, y = 0.0240, 温度 = 99.4°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7941, y = 0.9167, 温度 = 67.8°C, 段别 = 精馏段
# 第 4级: x = 0.7070, y = 0.8807, 温度 = 69.3°C, 段别 = 精馏段
# 第 5级: x = 0.6157, y = 0.8420, 温度 = 70.9°C, 段别 = 精馏段
# 第 6级: x = 0.5252, y = 0.8014, 温度 = 72.6°C, 段别 = 精馏段
# 第 7级: x = 0.4443, y = 0.7612, 温度 = 74.4°C, 段别 = 提馏段
# 第 8级: x = 0.3193, y = 0.6855, 温度 = 77.6°C, 段别 = 提馏段
# 第 9级: x = 0.1353, y = 0.4911, 温度 = 85.4°C, 段别 = 提馏段
# 第10级: x = 0.0333, y = 0.2049, 温度 = 94.6°C, 段别 = 提馏段
# 第11级: x = 0.0063, y = 0.0463, 温度 = 98.8°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7887, y = 0.9145, 温度 = 67.9°C, 段别 = 精馏段
# 第 4级: x = 0.6886, y = 0.8736, 温度 = 69.6°C, 段别 = 精馏段
# 第 5级: x = 0.5804, y = 0.8262, 温度 = 71.6°C, 段别 = 精馏段
# 第 6级: x = 0.4719, y = 0.7749, 温度 = 73.8°C, 段别 = 提馏段
# 第 7级: x = 0.3633, y = 0.7150, 温度 = 76.3°C, 段别 = 提馏段
# 第 8级: x = 0.1748, y = 0.5493, 温度 = 83.2°C, 段别 = 提馏段
# 第 9级: x = 0.0465, y = 0.2615, 温度 = 92.9°C, 段别 = 提馏段
# 第10级: x = 0.0091, y = 0.0656, 温度 = 98.3°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7838, y = 0.9125, 温度 = 67.9°C, 段别 = 精馏段
# 第 4级: x = 0.6730, y = 0.8669, 温度 = 69.8°C, 段别 = 精馏段
# 第 5级: x = 0.5479, y = 0.8115, 温度 = 72.1°C, 段别 = 精馏段
# 第 6级: x = 0.4217, y = 0.7489, 温度 = 74.9°C, 段别 = 提馏段
# 第 7级: x = 0.2459, y = 0.6275, 温度 = 80.1°C, 段别 = 提馏段
# 第 8级: x = 0.0770, y = 0.3638, 温度 = 89.8°C, 段别 = 提馏段
# 第 9级: x = 0.0159, y = 0.1105, 温度 = 97.1°C, 段别 = 提馏段
# 第10级: x = 0.0025, y = 0.0189, 温度 = 99.5°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7793, y = 0.9107, 温度 = 68.0°C, 段别 = 精馏段
# 第 4级: x = 0.6591, y = 0.8606, 温度 = 70.1°C, 段别 = 精馏段
# 第 5级: x = 0.5171, y = 0.7976, 温度 = 72.8°C, 段别 = 精馏段
# 第 6级: x = 0.3771, y = 0.7232, 温度 = 76.0°C, 段别 = 提馏段
# 第 7级: x = 0.1768, y = 0.5518, 温度 = 83.1°C, 段别 = 提馏段
# 第 8级: x = 0.0451, y = 0.2562, 温度 = 93.1°C, 段别 = 提馏段
# 第 9级: x = 0.0085, y = 0.0618, 温度 = 98.4°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7753, y = 0.9091, 温度 = 68.1°C, 段别 = 精馏段
# 第 4级: x = 0.6442, y = 0.8547, 温度 = 70.3°C, 段别 = 精馏段
# 第 5级: x = 0.4885, y = 0.7832, 温度 = 73.4°C, 段别 = 精馏段
# 第 6级: x = 0.3375, y = 0.6983, 温度 = 77.1°C, 段别 = 提馏段
# 第 7级: x = 0.1325, y = 0.4863, 温度 = 85.5°C, 段别 = 提馏段
# 第 8级: x = 0.0299, y = 0.1882, 温度 = 95.0°C, 段别 = 提馏段
# 第 9级: x = 0.0053, y = 0.0389, 温度 = 99.0°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7716, y = 0.9076, 温度 = 68.2°C, 段别 = 精馏段
# 第 4级: x = 0.6312, y = 0.8492, 温度 = 70.6°C, 段别 = 精馏段
# 第 5级: x = 0.4617, y = 0.7698, 温度 = 74.0°C, 段别 = 提馏段
# 第 6级: x = 0.2825, y = 0.6580, 温度 = 78.7°C, 段别 = 提馏段
# 第 7级: x = 0.0914, y = 0.4010, 温度 = 88.5°C, 段别 = 提馏段
# 第 8级: x = 0.0186, y = 0.1268, 温度 = 96.7°C, 段别 = 提馏段
# 第 9级: x = 0.0030, y = 0.0223, 温度 = 99.4°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7682, y = 0.9063, 温度 = 68.2°C, 段别 = 精馏段
# 第 4级: x = 0.6199, y = 0.8440, 温度 = 70.8°C, 段别 = 精馏段
# 第 5级: x = 0.4371, y = 0.7575, 温度 = 74.6°C, 段别 = 提馏段
# 第 6级: x = 0.2329, y = 0.6151, 温度 = 80.6°C, 段别 = 提馏段
# 第 7级: x = 0.0644, y = 0.3257, 温度 = 91.0°C, 段别 = 提馏段
# 第 8级: x = 0.0123, y = 0.0871, 温度 = 97.8°C, 段别 = 提馏段
# 第 9级: x = 0.0018, y = 0.0132, 温度 = 99.7°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7651, y = 0.9050, 温度 = 68.3°C, 段别 = 精馏段
# 第 4级: x = 0.6091, y = 0.8391, 温度 = 71.0°C, 段别 = 精馏段
# 第 5级: x = 0.4154, y = 0.7455, 温度 = 75.0°C, 段别 = 提馏段
# 第 6级: x = 0.1978, y = 0.5775, 温度 = 82.0°C, 段别 = 提馏段
# 第 7级: x = 0.0494, y = 0.2730, 温度 = 92.6°C, 段别 = 提馏段
# 第 8级: x = 0.0090, y = 0.0652, 温度 = 98.3°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7622, y = 0.9039, 温度 = 68.4°C, 段别 = 精馏段
# 第 4级: x = 0.5987, y = 0.8344, 温度 = 71.2°C, 段别 = 精馏段
# 第 5级: x = 0.3946, y = 0.7338, 温度 = 75.5°C, 段别 = 提馏段
# 第 6级: x = 0.1697, y = 0.5425, 温度 = 83.4°C, 段别 = 提馏段
# 第 7级: x = 0.0391, y = 0.2311, 温度 = 93.8°C, 段别 = 提馏段
# 第 8级: x = 0.0069, y = 0.0503, 温度 = 98.7°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7595, y = 0.9028, 温度 = 68.4°C, 段别 = 精馏段
# 第 4级: x = 0.5890, y = 0.8300, 温度 = 71.4°C, 段别 = 精馏段
# 第 5级: x = 0.3761, y = 0.7227, 温度 = 76.0°C, 段别 = 提馏段
# 第 6级: x = 0.1482, y = 0.5118, 温度 = 84.6°C, 段别 = 提馏段
# 第 7级: x = 0.0321, y = 0.1993, 温度 = 94.7°C, 段别 = 提馏段
# 第 8级: x = 0.0055, y = 0.0403, 温度 = 99.0°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7569, y = 0.9018, 温度 = 68.5°C, 段别 = 精馏段
# 第 4级: x = 0.5798, y = 0.8259, 温度 = 71.6°C, 段别 = 精馏段
# 第 5级: x = 0.3584, y = 0.7120, 温度 = 76.4°C, 段别 = 提馏段
# 第 6级: x = 0.1305, y = 0.4828, 温度 = 85.7°C, 段别 = 提馏段
# 第 7级: x = 0.0270, y = 0.1736, 温度 = 95.5°C, 段别 = 提馏段
# 第 8级: x = 0.0045, y = 0.0331, 温度 = 99.1°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7546, y = 0.9009, 温度 = 68.5°C, 段别 = 精馏段
# 第 4级: x = 0.5710, y = 0.8220, 温度 = 71.7°C, 段别 = 精馏段
# 第 5级: x = 0.3425, y = 0.7017, 温度 = 76.9°C, 段别 = 提馏段
# 第 6级: x = 0.1171, y = 0.4572, 温度 = 86.5°C, 段别 = 提馏段
# 第 7级: x = 0.0233, y = 0.1540, 温度 = 96.0°C, 段别 = 提馏段
# 第 8级: x = 0.0038, y = 0.0279, 温度 = 99.3°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7524, y = 0.9000, 温度 = 68.5°C, 段别 = 精馏段
# 第 4级: x = 0.5628, y = 0.8183, 温度 = 71.9°C, 段别 = 精馏段
# 第 5级: x = 0.3283, y = 0.6919, 温度 = 77.4°C, 段别 = 提馏段
# 第 6级: x = 0.1061, y = 0.4345, 温度 = 87.3°C, 段别 = 提馏段
# 第 7级: x = 0.0205, y = 0.1382, 温度 = 96.4°C, 段别 = 提馏段
# 第 8级: x = 0.0032, y = 0.0241, 温度 = 99.4°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7503, y = 0.8992, 温度 = 68.6°C, 段别 = 精馏段
# 第 4级: x = 0.5550, y = 0.8147, 温度 = 72.0°C, 段别 = 精馏段
# 第 5级: x = 0.3148, y = 0.6824, 温度 = 77.8°C, 段别 = 提馏段
# 第 6级: x = 0.0965, y = 0.4131, 温度 = 88.1°C, 段别 = 提馏段
# 第 7级: x = 0.0182, y = 0.1245, 温度 = 96.8°C, 段别 = 提馏段
# 第 8级: x = 0.0028, y = 0.0209, 温度 = 99.5°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7484, y = 0.8985, 温度 = 68.6°C, 段别 = 精馏段
# 第 4级: x = 0.5476, y = 0.8114, 温度 = 72.1°C, 段别 = 精馏段
# 第 5级: x = 0.3019, y = 0.6734, 温度 = 78.1°C, 段别 = 提馏段
# 第 6级: x = 0.0881, y = 0.3931, 温度 = 88.8°C, 段别 = 提馏段
# 第 7级: x = 0.0163, y = 0.1126, 温度 = 97.1°C, 段别 = 提馏段
# 第 8级: x = 0.0025, y = 0.0182, 温度 = 99.5°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7466, y = 0.8977, 温度 = 68.6°C, 段别 = 精馏段
# 第 4级: x = 0.5406, y = 0.8083, 温度 = 72.3°C, 段别 = 精馏段
# 第 5级: x = 0.2906, y = 0.6647, 温度 = 78.5°C, 段别 = 提馏段
# 第 6级: x = 0.0814, y = 0.3756, 温度 = 89.4°C, 段别 = 提馏段
# 第 7级: x = 0.0147, y = 0.1030, 温度 = 97.3°C, 段别 = 提馏段
# 第 8级: x = 0.0022, y = 0.0162, 温度 = 99.6°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7450, y = 0.8971, 温度 = 68.6°C, 段别 = 精馏段
# 第 4级: x = 0.5339, y = 0.8053, 温度 = 72.4°C, 段别 = 精馏段
# 第 5级: x = 0.2803, y = 0.6563, 温度 = 78.8°C, 段别 = 提馏段
# 第 6级: x = 0.0756, y = 0.3598, 温度 = 89.9°C, 段别 = 提馏段
# 第 7级: x = 0.0135, y = 0.0949, 温度 = 97.6°C, 段别 = 提馏段
# 第 8级: x = 0.0019, y = 0.0145, 温度 = 99.6°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7435, y = 0.8965, 温度 = 68.7°C, 段别 = 精馏段
# 第 4级: x = 0.5275, y = 0.8025, 温度 = 72.6°C, 段别 = 精馏段
# 第 5级: x = 0.2702, y = 0.6482, 温度 = 79.1°C, 段别 = 提馏段
# 第 6级: x = 0.0704, y = 0.3446, 温度 = 90.4°C, 段别 = 提馏段
# 第 7级: x = 0.0124, y = 0.0877, 温度 = 97.7°C, 段别 = 提馏段
# 第 8级: x = 0.0017, y = 0.0130, 温度 = 99.7°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7420, y = 0.8959, 温度 = 68.7°C, 段别 = 精馏段
# 第 4级: x = 0.5217, y = 0.7998, 温度 = 72.7°C, 段别 = 精馏段
# 第 5级: x = 0.2608, y = 0.6407, 温度 = 79.5°C, 段别 = 提馏段
# 第 6级: x = 0.0659, y = 0.3305, 温度 = 90.8°C, 段别 = 提馏段
# 第 7级: x = 0.0114, y = 0.0814, 温度 = 97.9°C, 段别 = 提馏段
# 第 8级: x = 0.0016, y = 0.0118, 温度 = 99.7°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7407, y = 0.8953, 温度 = 68.7°C, 段别 = 精馏段
# 第 4级: x = 0.5164, y = 0.7973, 温度 = 72.8°C, 段别 = 精馏段
# 第 5级: x = 0.2525, y = 0.6336, 温度 = 79.8°C, 段别 = 提馏段
# 第 6级: x = 0.0621, y = 0.3181, 温度 = 91.2°C, 段别 = 提馏段
# 第 7级: x = 0.0106, y = 0.0762, 温度 = 98.0°C, 段别 = 提馏段
# 第 8级: x = 0.0014, y = 0.0108, 温度 = 99.7°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7394, y = 0.8948, 温度 = 68.7°C, 段别 = 精馏段
# 第 4级: x = 0.5115, y = 0.7949, 温度 = 72.9°C, 段别 = 精馏段
# 第 5级: x = 0.2452, y = 0.6269, 温度 = 80.1°C, 段别 = 提馏段
# 第 6级: x = 0.0589, y = 0.3071, 温度 = 91.5°C, 段别 = 提馏段
# 第 7级: x = 0.0100, y = 0.0717, 温度 = 98.2°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7383, y = 0.8943, 温度 = 68.7°C, 段别 = 精馏段
# 第 4级: x = 0.5070, y = 0.7926, 温度 = 72.9°C, 段别 = 精馏段
# 第 5级: x = 0.2385, y = 0.6206, 温度 = 80.4°C, 段别 = 提馏段
# 第 6级: x = 0.0560, y = 0.2971, 温度 = 91.8°C, 段别 = 提馏段
# 第 7级: x = 0.0094, y = 0.0678, 温度 = 98.3°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7372, y = 0.8938, 温度 = 68.7°C, 段别 = 精馏段
# 第 4级: x = 0.5027, y = 0.7904, 温度 = 73.0°C, 段别 = 精馏段
# 第 5级: x = 0.2323, y = 0.6145, 温度 = 80.6°C, 段别 = 提馏段
# 第 6级: x = 0.0534, y = 0.2879, 温度 = 92.1°C, 段别 = 提馏段
# 第 7级: x = 0.0089, y = 0.0643, 温度 = 98.3°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7362, y = 0.8933, 温度 = 68.8°C, 段别 = 精馏段
# 第 4级: x = 0.4986, y = 0.7883, 温度 = 73.1°C, 段别 = 精馏段
# 第 5级: x = 0.2265, y = 0.6087, 温度 = 80.8°C, 段别 = 提馏段
# 第 6级: x = 0.0511, y = 0.2793, 温度 = 92.4°C, 段别 = 提馏段
# 第 7级: x = 0.0084, y = 0.0611, 温度 = 98.4°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7352, y = 0.8929, 温度 = 68.8°C, 段别 = 精馏段
# 第 4级: x = 0.4947, y = 0.7863, 温度 = 73.2°C, 段别 = 精馏段
# 第 5级: x = 0.2211, y = 0.6031, 温度 = 81.1°C, 段别 = 提馏段
# 第 6级: x = 0.0490, y = 0.2713, 温度 = 92.6°C, 段别 = 提馏段
# 第 7级: x = 0.0080, y = 0.0583, 温度 = 98.5°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7343, y = 0.8925, 温度 = 68.8°C, 段别 = 精馏段
# 第 4级: x = 0.4909, y = 0.7844, 温度 = 73.3°C, 段别 = 精馏段
# 第 5级: x = 0.2159, y = 0.5977, 温度 = 81.3°C, 段别 = 提馏段
# 第 6级: x = 0.0470, y = 0.2638, 温度 = 92.8°C, 段别 = 提馏段
# 第 7级: x = 0.0076, y = 0.0557, 温度 = 98.6°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7334, y = 0.8921, 温度 = 68.8°C, 段别 = 精馏段
# 第 4级: x = 0.4873, y = 0.7826, 温度 = 73.4°C, 段别 = 精馏段
# 第 5级: x = 0.2111, y = 0.5924, 温度 = 81.4°C, 段别 = 提馏段
# 第 6级: x = 0.0453, y = 0.2568, 温度 = 93.1°C, 段别 = 提馏段
# 第 7级: x = 0.0073, y = 0.0533, 温度 = 98.6°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7326, y = 0.8917, 温度 = 68.8°C, 段别 = 精馏段
# 第 4级: x = 0.4838, y = 0.7809, 温度 = 73.5°C, 段别 = 精馏段
# 第 5级: x = 0.2065, y = 0.5874, 温度 = 81.6°C, 段别 = 提馏段
# 第 6级: x = 0.0436, y = 0.2502, 温度 = 93.2°C, 段别 = 提馏段
# 第 7级: x = 0.0070, y = 0.0511, 温度 = 98.7°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7318, y = 0.8913, 温度 = 68.8°C, 段别 = 精馏段
# 第 4级: x = 0.4804, y = 0.7792, 温度 = 73.6°C, 段别 = 精馏段
# 第 5级: x = 0.2022, y = 0.5825, 温度 = 81.8°C, 段别 = 提馏段
# 第 6级: x = 0.0421, y = 0.2440, 温度 = 93.4°C, 段别 = 提馏段
# 第 7级: x = 0.0067, y = 0.0491, 温度 = 98.7°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7310, y = 0.8910, 温度 = 68.8°C, 段别 = 精馏段
# 第 4级: x = 0.4772, y = 0.7776, 温度 = 73.7°C, 段别 = 提馏段
# 第 5级: x = 0.1971, y = 0.5766, 温度 = 82.0°C, 段别 = 提馏段
# 第 6级: x = 0.0404, y = 0.2369, 温度 = 93.6°C, 段别 = 提馏段
# 第 7级: x = 0.0064, y = 0.0469, 温度 = 98.8°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7303, y = 0.8906, 温度 = 68.8°C, 段别 = 精馏段
# 第 4级: x = 0.4742, y = 0.7761, 温度 = 73.7°C, 段别 = 提馏段
# 第 5级: x = 0.1922, y = 0.5709, 温度 = 82.3°C, 段别 = 提馏段
# 第 6级: x = 0.0389, y = 0.2301, 温度 = 93.8°C, 段别 = 提馏段
# 第 7级: x = 0.0061, y = 0.0449, 温度 = 98.8°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7296, y = 0.8903, 温度 = 68.8°C, 段别 = 精馏段
# 第 4级: x = 0.4712, y = 0.7746, 温度 = 73.8°C, 段别 = 提馏段
# 第 5级: x = 0.1875, y = 0.5653, 温度 = 82.5°C, 段别 = 提馏段
# 第 6级: x = 0.0374, y = 0.2238, 温度 = 94.0°C, 段别 = 提馏段
# 第 7级: x = 0.0059, y = 0.0430, 温度 = 98.9°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# ...
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7159, y = 0.8843, 温度 = 69.1°C, 段别 = 精馏段
# 第 4级: x = 0.4142, y = 0.7448, 温度 = 75.0°C, 段别 = 提馏段
# 第 5级: x = 0.1206, y = 0.4641, 温度 = 86.3°C, 段别 = 提馏段
# 第 6级: x = 0.0199, y = 0.1342, 温度 = 96.5°C, 段别 = 提馏段
# 第 7级: x = 0.0028, y = 0.0211, 温度 = 99.5°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7157, y = 0.8842, 温度 = 69.1°C, 段别 = 精馏段
# 第 4级: x = 0.4131, y = 0.7442, 温度 = 75.1°C, 段别 = 提馏段
# 第 5级: x = 0.1196, y = 0.4623, 温度 = 86.3°C, 段别 = 提馏段
# 第 6级: x = 0.0197, y = 0.1330, 温度 = 96.6°C, 段别 = 提馏段
# 第 7级: x = 0.0028, y = 0.0208, 温度 = 99.5°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7154, y = 0.8841, 温度 = 69.1°C, 段别 = 精馏段
# 第 4级: x = 0.4120, y = 0.7437, 温度 = 75.1°C, 段别 = 提馏段
# 第 5级: x = 0.1187, y = 0.4605, 温度 = 86.4°C, 段别 = 提馏段
# 第 6级: x = 0.0195, y = 0.1318, 温度 = 96.6°C, 段别 = 提馏段
# 第 7级: x = 0.0028, y = 0.0206, 温度 = 99.5°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7151, y = 0.8840, 温度 = 69.1°C, 段别 = 精馏段
# 第 4级: x = 0.4110, y = 0.7431, 温度 = 75.1°C, 段别 = 提馏段
# 第 5级: x = 0.1178, y = 0.4587, 温度 = 86.4°C, 段别 = 提馏段
# 第 6级: x = 0.0193, y = 0.1307, 温度 = 96.6°C, 段别 = 提馏段
# 第 7级: x = 0.0027, y = 0.0204, 温度 = 99.5°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7149, y = 0.8839, 温度 = 69.1°C, 段别 = 精馏段
# 第 4级: x = 0.4100, y = 0.7425, 温度 = 75.1°C, 段别 = 提馏段
# 第 5级: x = 0.1170, y = 0.4570, 温度 = 86.5°C, 段别 = 提馏段
# 第 6级: x = 0.0191, y = 0.1296, 温度 = 96.6°C, 段别 = 提馏段
# 第 7级: x = 0.0027, y = 0.0201, 温度 = 99.5°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7146, y = 0.8837, 温度 = 69.1°C, 段别 = 精馏段
# 第 4级: x = 0.4090, y = 0.7420, 温度 = 75.2°C, 段别 = 提馏段
# 第 5级: x = 0.1162, y = 0.4554, 温度 = 86.6°C, 段别 = 提馏段
# 第 6级: x = 0.0189, y = 0.1285, 温度 = 96.7°C, 段别 = 提馏段
# 第 7级: x = 0.0027, y = 0.0199, 温度 = 99.5°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7144, y = 0.8836, 温度 = 69.1°C, 段别 = 精馏段
# 第 4级: x = 0.4080, y = 0.7415, 温度 = 75.2°C, 段别 = 提馏段
# 第 5级: x = 0.1154, y = 0.4538, 温度 = 86.6°C, 段别 = 提馏段
# 第 6级: x = 0.0187, y = 0.1275, 温度 = 96.7°C, 段别 = 提馏段
# 第 7级: x = 0.0027, y = 0.0197, 温度 = 99.5°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7141, y = 0.8835, 温度 = 69.1°C, 段别 = 精馏段
# 第 4级: x = 0.4071, y = 0.7409, 温度 = 75.2°C, 段别 = 提馏段
# 第 5级: x = 0.1146, y = 0.4522, 温度 = 86.7°C, 段别 = 提馏段
# 第 6级: x = 0.0186, y = 0.1265, 温度 = 96.7°C, 段别 = 提馏段
# 第 7级: x = 0.0026, y = 0.0195, 温度 = 99.5°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7139, y = 0.8835, 温度 = 69.1°C, 段别 = 精馏段
# 第 4级: x = 0.4061, y = 0.7404, 温度 = 75.2°C, 段别 = 提馏段
# 第 5级: x = 0.1138, y = 0.4506, 温度 = 86.7°C, 段别 = 提馏段
# 第 6级: x = 0.0184, y = 0.1255, 温度 = 96.8°C, 段别 = 提馏段
# 第 7级: x = 0.0026, y = 0.0193, 温度 = 99.5°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7137, y = 0.8834, 温度 = 69.1°C, 段别 = 精馏段
# 第 4级: x = 0.4052, y = 0.7399, 温度 = 75.3°C, 段别 = 提馏段
# 第 5级: x = 0.1131, y = 0.4491, 温度 = 86.8°C, 段别 = 提馏段
# 第 6级: x = 0.0182, y = 0.1245, 温度 = 96.8°C, 段别 = 提馏段
# 第 7级: x = 0.0026, y = 0.0191, 温度 = 99.5°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7134, y = 0.8833, 温度 = 69.1°C, 段别 = 精馏段
# 第 4级: x = 0.4043, y = 0.7394, 温度 = 75.3°C, 段别 = 提馏段
# 第 5级: x = 0.1124, y = 0.4477, 温度 = 86.8°C, 段别 = 提馏段
# 第 6级: x = 0.0181, y = 0.1236, 温度 = 96.8°C, 段别 = 提馏段
# 第 7级: x = 0.0026, y = 0.0190, 温度 = 99.5°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7132, y = 0.8832, 温度 = 69.1°C, 段别 = 精馏段
# 第 4级: x = 0.4035, y = 0.7390, 温度 = 75.3°C, 段别 = 提馏段
# 第 5级: x = 0.1117, y = 0.4462, 温度 = 86.9°C, 段别 = 提馏段
# 第 6级: x = 0.0179, y = 0.1227, 温度 = 96.8°C, 段别 = 提馏段
# 第 7级: x = 0.0025, y = 0.0188, 温度 = 99.5°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7130, y = 0.8831, 温度 = 69.1°C, 段别 = 精馏段
# 第 4级: x = 0.4026, y = 0.7385, 温度 = 75.3°C, 段别 = 提馏段
# 第 5级: x = 0.1110, y = 0.4449, 温度 = 86.9°C, 段别 = 提馏段
# 第 6级: x = 0.0178, y = 0.1219, 温度 = 96.8°C, 段别 = 提馏段
# 第 7级: x = 0.0025, y = 0.0186, 温度 = 99.5°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7128, y = 0.8830, 温度 = 69.1°C, 段别 = 精馏段
# 第 4级: x = 0.4018, y = 0.7380, 温度 = 75.4°C, 段别 = 提馏段
# 第 5级: x = 0.1104, y = 0.4435, 温度 = 87.0°C, 段别 = 提馏段
# 第 6级: x = 0.0177, y = 0.1210, 温度 = 96.9°C, 段别 = 提馏段
# 第 7级: x = 0.0025, y = 0.0185, 温度 = 99.5°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7126, y = 0.8829, 温度 = 69.1°C, 段别 = 精馏段
# 第 4级: x = 0.4010, y = 0.7376, 温度 = 75.4°C, 段别 = 提馏段
# 第 5级: x = 0.1097, y = 0.4422, 温度 = 87.0°C, 段别 = 提馏段
# 第 6级: x = 0.0175, y = 0.1202, 温度 = 96.9°C, 段别 = 提馏段
# 第 7级: x = 0.0025, y = 0.0183, 温度 = 99.5°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7124, y = 0.8828, 温度 = 69.2°C, 段别 = 精馏段
# 第 4级: x = 0.4002, y = 0.7371, 温度 = 75.4°C, 段别 = 提馏段
# 第 5级: x = 0.1091, y = 0.4409, 温度 = 87.1°C, 段别 = 提馏段
# 第 6级: x = 0.0174, y = 0.1195, 温度 = 96.9°C, 段别 = 提馏段
# 第 7级: x = 0.0024, y = 0.0182, 温度 = 99.5°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7122, y = 0.8828, 温度 = 69.2°C, 段别 = 精馏段
# 第 4级: x = 0.3995, y = 0.7367, 温度 = 75.4°C, 段别 = 提馏段
# 第 5级: x = 0.1085, y = 0.4396, 温度 = 87.1°C, 段别 = 提馏段
# 第 6级: x = 0.0173, y = 0.1187, 温度 = 96.9°C, 段别 = 提馏段
# 第 7级: x = 0.0024, y = 0.0180, 温度 = 99.5°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7120, y = 0.8827, 温度 = 69.2°C, 段别 = 精馏段
# 第 4级: x = 0.3987, y = 0.7363, 温度 = 75.4°C, 段别 = 提馏段
# 第 5级: x = 0.1080, y = 0.4384, 温度 = 87.2°C, 段别 = 提馏段
# 第 6级: x = 0.0171, y = 0.1179, 温度 = 97.0°C, 段别 = 提馏段
# 第 7级: x = 0.0024, y = 0.0179, 温度 = 99.5°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7118, y = 0.8826, 温度 = 69.2°C, 段别 = 精馏段
# 第 4级: x = 0.3980, y = 0.7359, 温度 = 75.5°C, 段别 = 提馏段
# 第 5级: x = 0.1074, y = 0.4372, 温度 = 87.2°C, 段别 = 提馏段
# 第 6级: x = 0.0170, y = 0.1172, 温度 = 97.0°C, 段别 = 提馏段
# 第 7级: x = 0.0024, y = 0.0177, 温度 = 99.5°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7116, y = 0.8825, 温度 = 69.2°C, 段别 = 精馏段
# 第 4级: x = 0.3973, y = 0.7354, 温度 = 75.5°C, 段别 = 提馏段
# 第 5级: x = 0.1068, y = 0.4360, 温度 = 87.3°C, 段别 = 提馏段
# 第 6级: x = 0.0169, y = 0.1165, 温度 = 97.0°C, 段别 = 提馏段
# 第 7级: x = 0.0024, y = 0.0176, 温度 = 99.5°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7114, y = 0.8825, 温度 = 69.2°C, 段别 = 精馏段
# 第 4级: x = 0.3966, y = 0.7350, 温度 = 75.5°C, 段别 = 提馏段
# 第 5级: x = 0.1063, y = 0.4349, 温度 = 87.3°C, 段别 = 提馏段
# 第 6级: x = 0.0168, y = 0.1158, 温度 = 97.0°C, 段别 = 提馏段
# 第 7级: x = 0.0023, y = 0.0175, 温度 = 99.5°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7112, y = 0.8824, 温度 = 69.2°C, 段别 = 精馏段
# 第 4级: x = 0.3959, y = 0.7346, 温度 = 75.5°C, 段别 = 提馏段
# 第 5级: x = 0.1058, y = 0.4338, 温度 = 87.3°C, 段别 = 提馏段
# 第 6级: x = 0.0167, y = 0.1152, 温度 = 97.0°C, 段别 = 提馏段
# 第 7级: x = 0.0023, y = 0.0173, 温度 = 99.5°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7111, y = 0.8823, 温度 = 69.2°C, 段别 = 精馏段
# 第 4级: x = 0.3953, y = 0.7343, 温度 = 75.5°C, 段别 = 提馏段
# 第 5级: x = 0.1053, y = 0.4327, 温度 = 87.4°C, 段别 = 提馏段
# 第 6级: x = 0.0166, y = 0.1145, 温度 = 97.0°C, 段别 = 提馏段
# 第 7级: x = 0.0023, y = 0.0172, 温度 = 99.6°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7109, y = 0.8822, 温度 = 69.2°C, 段别 = 精馏段
# 第 4级: x = 0.3946, y = 0.7339, 温度 = 75.5°C, 段别 = 提馏段
# 第 5级: x = 0.1048, y = 0.4316, 温度 = 87.4°C, 段别 = 提馏段
# 第 6级: x = 0.0165, y = 0.1139, 温度 = 97.1°C, 段别 = 提馏段
# 第 7级: x = 0.0023, y = 0.0171, 温度 = 99.6°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7107, y = 0.8822, 温度 = 69.2°C, 段别 = 精馏段
# 第 4级: x = 0.3940, y = 0.7335, 温度 = 75.6°C, 段别 = 提馏段
# 第 5级: x = 0.1043, y = 0.4306, 温度 = 87.5°C, 段别 = 提馏段
# 第 6级: x = 0.0164, y = 0.1133, 温度 = 97.1°C, 段别 = 提馏段
# 第 7级: x = 0.0023, y = 0.0170, 温度 = 99.6°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7105, y = 0.8821, 温度 = 69.2°C, 段别 = 精馏段
# 第 4级: x = 0.3934, y = 0.7331, 温度 = 75.6°C, 段别 = 提馏段
# 第 5级: x = 0.1039, y = 0.4296, 温度 = 87.5°C, 段别 = 提馏段
# 第 6级: x = 0.0163, y = 0.1127, 温度 = 97.1°C, 段别 = 提馏段
# 第 7级: x = 0.0023, y = 0.0169, 温度 = 99.6°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7104, y = 0.8820, 温度 = 69.2°C, 段别 = 精馏段
# 第 4级: x = 0.3928, y = 0.7328, 温度 = 75.6°C, 段别 = 提馏段
# 第 5级: x = 0.1034, y = 0.4286, 温度 = 87.5°C, 段别 = 提馏段
# 第 6级: x = 0.0162, y = 0.1121, 温度 = 97.1°C, 段别 = 提馏段
# 第 7级: x = 0.0023, y = 0.0168, 温度 = 99.6°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7102, y = 0.8820, 温度 = 69.2°C, 段别 = 精馏段
# 第 4级: x = 0.3922, y = 0.7324, 温度 = 75.6°C, 段别 = 提馏段
# 第 5级: x = 0.1030, y = 0.4276, 温度 = 87.6°C, 段别 = 提馏段
# 第 6级: x = 0.0161, y = 0.1116, 温度 = 97.1°C, 段别 = 提馏段
# 第 7级: x = 0.0022, y = 0.0167, 温度 = 99.6°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7100, y = 0.8819, 温度 = 69.2°C, 段别 = 精馏段
# 第 4级: x = 0.3916, y = 0.7321, 温度 = 75.6°C, 段别 = 提馏段
# 第 5级: x = 0.1025, y = 0.4266, 温度 = 87.6°C, 段别 = 提馏段
# 第 6级: x = 0.0160, y = 0.1110, 温度 = 97.1°C, 段别 = 提馏段
# 第 7级: x = 0.0022, y = 0.0166, 温度 = 99.6°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
# 从塔顶开始塔板迭代计算 (考虑液相Murphree效率)...
# 目标釜液组成 x_W = 0.01
# 液相Murphree效率 E_ml = 1.0
# --------------------------------------------------------------------------------
# 第 1级: x = 0.9500, y = 0.9500, 温度 = 65.3°C, 段别 = 精馏段
# 第 2级: x = 0.8750, y = 0.9500, 温度 = 66.5°C, 段别 = 精馏段
# 第 3级: x = 0.7099, y = 0.8818, 温度 = 69.2°C, 段别 = 精馏段
# 第 4级: x = 0.3910, y = 0.7317, 温度 = 75.6°C, 段别 = 提馏段
# 第 5级: x = 0.1021, y = 0.4257, 温度 = 87.6°C, 段别 = 提馏段
# 第 6级: x = 0.0159, y = 0.1105, 温度 = 97.1°C, 段别 = 提馏段
# 第 7级: x = 0.0022, y = 0.0165, 温度 = 99.6°C, 段别 = 提馏段
# 达到目标釜液组成 x_W = 0.01
